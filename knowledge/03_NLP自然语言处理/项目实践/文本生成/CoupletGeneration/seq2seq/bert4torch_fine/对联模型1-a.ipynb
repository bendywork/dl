# %%
import json, os
from bert4torch.models import build_transformer_model
from bert4torch.tokenizers import Tokenizer, load_vocab
from bert4torch.snippets import sequence_padding, seed_everything, ListDataset
from bert4torch.generation import AutoRegressiveDecoder
from bert4torch.callbacks import Callback
from tqdm import tqdm
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from rouge import Rouge  # pip install rouge
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction # pip install nltk
import jieba

jieba.initialize()
# Out:
# /usr/local/lib/python3.11/site-packages/torch/cuda/__init__.py:56: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.857 seconds.
# Prefix dict has been built successfully.

# %%
class MyDataset(ListDataset):
    @staticmethod
    def load_data(filename):
        D = []
        with open(filename, "r", encoding='utf-8') as reader:
            for line in reader:
                line = line.strip()
                try:
                    text1, text2 = line.split("，")
                    text2 = text2[:-1]
                    D.append((text1, text2))  # 上联 ---> 下联  5个字的对联
                    D.append((text1[:2], text2[:2]))  #  上联 ---> 下联  2个字的对联
                except:
                    pass
        return D

# %%
def collate_fn(batch):
    """单条样本格式：content：[CLS]文章[SEP]  tgt: [CLS]标题[SEP]
    """
    batch_content_ids, batch_titile_ids = [], []
    for upper, lower in batch:
        token_ids, _ = tokenizer.encode(upper, maxlen=max_c_len)
        batch_content_ids.append(token_ids)

        token_ids, _ = tokenizer.encode(lower, maxlen=max_t_len)
        batch_titile_ids.append(token_ids)

    batch_content_ids = torch.tensor(sequence_padding(batch_content_ids), dtype=torch.long, device=device)
    batch_titile_ids = torch.tensor(sequence_padding(batch_titile_ids), dtype=torch.long, device=device)
    return [[batch_content_ids], [batch_titile_ids[:, :-1]]], batch_titile_ids[:, 1:].flatten()

# %%
class CrossEntropyLoss(nn.CrossEntropyLoss):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def forward(self, outputs, y_true):
        y_pred = outputs[-1]
        y_pred = y_pred.reshape(-1, y_pred.shape[-1])
        return super().forward(y_pred, y_true)

# %%
class AutoTitle(AutoRegressiveDecoder):
    """seq2seq解码器
    """

    @AutoRegressiveDecoder.wraps(default_rtype='logits')
    def predict(self, inputs, output_ids, states):
        # inputs中包含了[decoder_ids, encoder_hidden_state, encoder_attention_mask]
        res = model.decoder.predict([output_ids] + inputs)
        return res[-1][:, -1, :] if isinstance(res, list) else res[:, -1, :]  # 保留最后一位

    def generate(self, text, topk=1):
        token_ids, _ = tokenizer.encode(text, maxlen=max_c_len)
        token_ids = torch.tensor([token_ids], device=device)
        encoder_output = model.encoder.predict([token_ids])
        output_ids = self.beam_search(encoder_output, topk=topk)[0]  # 基于beam search
        return tokenizer.decode([int(i) for i in output_ids.cpu().numpy()])

# %%
def just_show():
    texts = [
        '日晃百花色'
    ]
    for text in texts:
        print(text, "  ", autotitle.generate(text))


class Evaluator(Callback):
    """评估与保存
    """

    def __init__(self):
        super(Evaluator, self).__init__()
        self.rouge = Rouge()
        self.smooth = SmoothingFunction().method1
        self.best_bleu = 0.

    def on_epoch_end(self, steps, epoch, logs=None):
        just_show()
        metrics = self.evaluate(valid_dataset.data)  # 评测模型
        metrics_test = self.evaluate(test_dataset.data)  # 评测模型
        if metrics['bleu'] > self.best_bleu:
            self.best_bleu = metrics['bleu']
            model.save_weights('./best_model_v0.pt')  # 保存模型
        metrics['best_bleu'] = self.best_bleu
        print('valid_data:', metrics)
        print('test_data:', metrics_test)

    def evaluate(self, data, topk=1):
        total = 0
        rouge_1, rouge_2, rouge_l, bleu = 0, 0, 0, 0
        for upper, lower in tqdm(data):
            total += 1
            title = ' '.join(lower).lower()
            pred_title = ' '.join(autotitle.generate(upper, topk)).lower()
            if pred_title.strip():
                scores = self.rouge.get_scores(hyps=pred_title, refs=title)
                rouge_1 += scores[0]['rouge-1']['f']
                rouge_2 += scores[0]['rouge-2']['f']
                rouge_l += scores[0]['rouge-l']['f']
                bleu += sentence_bleu(
                    references=[title.split(' ')], hypothesis=pred_title.split(' '),
                    smoothing_function=self.smooth
                )
        rouge_1, rouge_2, rouge_l, bleu = rouge_1 / total, rouge_2 / total, rouge_l / total, bleu / total
        return {'rouge-1': rouge_1, 'rouge-2': rouge_2, 'rouge-l': rouge_l, 'bleu': bleu}

# %% [markdown]
# # 开始运行

# %%
# %% 属性定义

max_c_len = 256
max_t_len = 32
batch_size = 64
epochs = 50
steps_per_epoch = None

pretrain_model = r"/mnt/workspace/models/chinese_t5_pegasus_small"
config_path = os.path.join(pretrain_model, 'bert4torch_config.json')
checkpoint_path = os.path.join(pretrain_model, 'pytorch_model.bin')
dict_path = os.path.join(pretrain_model, 'vocab.txt')
device = 'cuda' if torch.cuda.is_available() else 'cpu'
seed_everything(42)
# Out:
# [INFO] Global seed set to 42
# 42

# %%
tokenizer = Tokenizer(
    dict_path,
    do_lower_case=True,
    pre_tokenize=lambda s: jieba.cut(s, HMM=False)
)


train_dataset = MyDataset("../../datas/poetry_train.txt")

train_dataloader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    collate_fn=collate_fn
)
valid_dataset = MyDataset("../../datas/poetry_min.txt")
test_dataset = MyDataset("../../datas/poetry_min.txt")

# %%
model = build_transformer_model(config_path, checkpoint_path, add_trainer=True).to(device)
model.compile(loss=CrossEntropyLoss(ignore_index=0), optimizer=optim.Adam(model.parameters(), 1e-4))

# %%
model
# Out:
# BertBaseModel(
#   (encoder): T5_Encoder(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(50000, 512, padding_idx=0)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoderLayer): ModuleList(
#       (0-7): 8 x T5Layer(
#         (multiHeadAttention): T5Attention(
#           (q): Linear(in_features=512, out_features=384, bias=False)
#           (k): Linear(in_features=512, out_features=384, bias=False)
#           (v): Linear(in_features=512, out_features=384, bias=False)
#           (o): Linear(in_features=384, out_features=512, bias=False)
#           (relative_positions): T5PositionsEncoding()
#           (relative_positions_encoding): Embedding(32, 6)
#         )
#         (attnLayerNorm): LayerNorm((512,), eps=1e-12, norm_mode=rmsnorm, bias=False)
#         (feedForward): T5PositionWiseFeedForward(
#           (intermediateDense): Linear(in_features=512, out_features=1024, bias=False)
#           (outputDense): Linear(in_features=1024, out_features=512, bias=False)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (intermediateDense1): Linear(in_features=512, out_features=1024, bias=False)
#         )
#         (ffnLayerNorm): LayerNorm((512,), eps=1e-12, norm_mode=rmsnorm, bias=False)
#       )
#     )
#     (final_layer_norm): LayerNorm((512,), eps=1e-12, norm_mode=rmsnorm, bias=False)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5_Decoder(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(50000, 512, padding_idx=0)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (decoderLayer): ModuleList(
#       (0-7): 8 x T5Layer(
#         (multiHeadAttention): T5Attention(
#           (q): Linear(in_features=512, out_features=384, bias=False)
#           (k): Linear(in_features=512, out_features=384, bias=False)
#           (v): Linear(in_features=512, out_features=384, bias=False)
#           (o): Linear(in_features=384, out_features=512, bias=False)
#           (relative_positions): T5PositionsEncoding()
#           (relative_positions_encoding): Embedding(32, 6)
#         )
#         (attnLayerNorm): LayerNorm((512,), eps=1e-12, norm_mode=rmsnorm, bias=False)
#         (feedForward): T5PositionWiseFeedForward(
#           (intermediateDense): Linear(in_features=512, out_features=1024, bias=False)
#           (outputDense): Linear(in_features=1024, out_features=512, bias=False)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (intermediateDense1): Linear(in_features=512, out_features=1024, bias=False)
#         )
#         (ffnLayerNorm): LayerNorm((512,), eps=1e-12, norm_mode=rmsnorm, bias=False)
#         (crossAttention): T5Attention(
#           (q): Linear(in_features=512, out_features=384, bias=False)
#           (k): Linear(in_features=512, out_features=384, bias=False)
#           (v): Linear(in_features=512, out_features=384, bias=False)
#           (o): Linear(in_features=384, out_features=512, bias=False)
#         )
#         (crossLayerNorm): LayerNorm((512,), eps=1e-12, norm_mode=rmsnorm, bias=False)
#       )
#     )
#     (lm_head): Linear(in_features=512, out_features=50000, bias=False)
#     (final_layer_norm): LayerNorm((512,), eps=1e-12, norm_mode=rmsnorm, bias=False)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (criterion): CrossEntropyLoss()
# )

# %%
autotitle = AutoTitle(
    bos_token_id=tokenizer._token_start_id,
    eos_token_id=tokenizer._token_end_id,
    max_new_tokens=max_t_len,
    device=device,
    top_k=2
)

# %% [markdown]
# ## 训练代码

# %%
evaluator = Evaluator()
print(u'生成下联:', autotitle.generate(u'日晃百花色'))
model.fit(
    train_dataloader,
    steps_per_epoch=steps_per_epoch,
    epochs=epochs,
    callbacks=[evaluator]
)
# Out:
# 生成下联: 《花色天香》是由李小姐演唱的一首歌曲。
# 2026-01-28 20:30:12 - Start Training
#
# 2026-01-28 20:30:12 - Start  Epoch: 1/50
# 2254/2254 [==============================] - 4:01 107ms/step - loss: 4.4957
# 2026-01-28 20:34:14 - Finish Epoch: 1/50 - loss: 4.7703
# 日晃百花色    风飘百尺风
# 100%|██████████| 16/16 [00:01<00:00, 13.43it/s]
# 100%|██████████| 16/16 [00:01<00:00, 13.52it/s]
# valid_data: {'rouge-1': 0.031249999687500005, 'rouge-2': 0.0, 'rouge-l': 0.031249999687500005, 'bleu': 0.009345929882632631, 'best_bleu': 0.009345929882632631}
# test_data: {'rouge-1': 0.031249999687500005, 'rouge-2': 0.0, 'rouge-l': 0.031249999687500005, 'bleu': 0.009345929882632631}
#
# 2026-01-28 20:34:17 - Start  Epoch: 2/50
#   86/2254 [>.............................] - ETA: 0:09<3:49 - loss: 4.3139
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 3
#       1 evaluator = Evaluator()
#       2 print(u'生成下联:', autotitle.generate(u'日晃百花色'))
# ----> 3 model.fit(
#       4     train_dataloader,
#       5     steps_per_epoch=steps_per_epoch,
#       6     epochs=epochs,
#       7     callbacks=[evaluator]
#       8 )
#
# File /usr/local/lib/python3.11/site-packages/torch4keras/trainer/base.py:394, in Trainer.fit(self, train_dataloader, steps_per_epoch, epochs, callbacks, verbose, **kwargs)
#     379 ''' 模型训练
#     380 :param train_dataloader: Dataloader, 训练数据集
#     381 :param steps_per_epoch: int, 每个epoch训练的steps, 默认为None表示自行计算
#    (...)    391 :return: History
#     392 '''
#     393 try:
# --> 394     return self._fit(train_dataloader, steps_per_epoch, epochs, callbacks, verbose, **kwargs)
#     395 except Exception as e:
#     396     # 训练异常则发邮件
#     397     error_msg = traceback.format_exc()
#
# File /usr/local/lib/python3.11/site-packages/torch4keras/trainer/base.py:454, in Trainer._fit(self, train_dataloader, steps_per_epoch, epochs, callbacks, verbose, **kwargs)
#     452 tr_loss, tr_loss_detail = 0, {}
#     453 for _ in range(self.grad_accumulation_steps):
# --> 454     self.train_X, self.train_y = self.prepare_nextbatch()  # 获取下一个batch的训练数据
#     455     self._log_first_step(resume_step, self.train_X, self.train_y)  # log第一个step
#     456     output, loss, loss_detail = self.train_step(self.train_X, self.train_y)
#
# File /usr/local/lib/python3.11/site-packages/torch4keras/trainer/base.py:369, in Trainer.prepare_nextbatch(self)
#     366 # 若使用梯度累计grad_accumulation_steps，则batch_step和global_step会不一致
#     367 if self.batch_step > self.resume_batch:
#     368     # 从头开始
# --> 369     batch = _prepare_nextbatch()
#     370 else:
#     371     # 断点续训
#     372     while self.batch_step <= self.resume_batch:
#
# File /usr/local/lib/python3.11/site-packages/torch4keras/trainer/base.py:354, in Trainer.prepare_nextbatch.<locals>._prepare_nextbatch()
#     352 def _prepare_nextbatch():
#     353     try:
# --> 354         batch = next(self.train_dataloader_iter)
#     355     except StopIteration:
#     356         self.callbacks.on_dataloader_end()  # 适用于数据量较大时, 动态读取文件并重新生成self.train_dataloader的情况, 如预训练
#
# File /usr/local/lib/python3.11/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File /usr/local/lib/python3.11/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /usr/local/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
# ---> 54 return self.collate_fn(data)
#
# Cell In[3], line 9, in collate_fn(batch)
#       6     token_ids, _ = tokenizer.encode(upper, maxlen=max_c_len)
#       7     batch_content_ids.append(token_ids)
# ----> 9     token_ids, _ = tokenizer.encode(lower, maxlen=max_t_len)
#      10     batch_titile_ids.append(token_ids)
#      12 batch_content_ids = torch.tensor(sequence_padding(batch_content_ids), dtype=torch.long, device=device)
#
# File /usr/local/lib/python3.11/site-packages/bert4torch/tokenizers.py:232, in TokenizerBase.encode(self, first_texts, second_texts, maxlen, pattern, truncate_from, return_offsets, return_tensors, return_dict, **kwargs)
#     230 # 循环处理每条样本
#     231 for first_text, second_text in zip(first_texts, second_texts):
# --> 232     outputs = self._encode(first_text, second_text, maxlen, pattern, truncate_from, return_offsets)
#     233     first_token_ids.append(outputs[0])
#     234     first_segment_ids.append(outputs[1])
#
# File /usr/local/lib/python3.11/site-packages/bert4torch/tokenizers.py:148, in TokenizerBase._encode(self, first_text, second_text, maxlen, pattern, truncate_from, return_offsets)
#     139 def _encode(self,
#     140             first_text:str,
#     141             second_text:str=None,
#    (...)    144             truncate_from:Literal['left', 'right']='right',
#     145             return_offsets:Literal['transformers', True, False]=False):
#     146     """输出文本对应token id和segment id
#     147     """
# --> 148     first_tokens = self.tokenize(first_text) if is_string(first_text) else first_text
#     150     if second_text is None:
#     151         second_tokens = None
#
# File /usr/local/lib/python3.11/site-packages/bert4torch/tokenizers.py:117, in TokenizerBase.tokenize(self, text, maxlen)
#     114 def tokenize(self, text:str, maxlen:int=None) -> List[str]:
#     115     """分词函数
#     116     """
# --> 117     tokens = [self._token_translate.get(token) or token for token in self._tokenize(text)]
#     118     if self._token_start is not None:
#     119         tokens.insert(0, self._token_start)
#
# File /usr/local/lib/python3.11/site-packages/bert4torch/tokenizers.py:327, in Tokenizer._tokenize(self, text, pre_tokenize)
#     325 # 以下pre_tokenizer逻辑参考bert4keras
#     326 if self._do_lower_case:
# --> 327     text = lowercase_and_normalize(text, never_split=self.never_split)
#     329 if pre_tokenize and self._pre_tokenize is not None:
#     330     tokens = []
#
# File /usr/local/lib/python3.11/site-packages/bert4torch/snippets/data_process.py:289, in lowercase_and_normalize(text, never_split)
#     287 escaped_special_toks = [re.escape(s_tok) for s_tok in never_split]
#     288 pattern = r"(" + r"|".join(escaped_special_toks) + r")|" + r"(.+?)"
# --> 289 text = re.sub(pattern, lambda m: m.groups()[0] or m.groups()[1].lower(), text)
#     291 # text = text.lower()
#     292 text = unicodedata.normalize('NFD', text)
#
# File /usr/local/lib/python3.11/re/__init__.py:185, in sub(pattern, repl, string, count, flags)
#     178 def sub(pattern, repl, string, count=0, flags=0):
#     179     """Return the string obtained by replacing the leftmost
#     180     non-overlapping occurrences of the pattern in string by the
#     181     replacement repl.  repl can be either a string or a callable;
#     182     if a string, backslash escapes in it are processed.  If it is
#     183     a callable, it's passed the Match object and must return
#     184     a replacement string to be used."""
# --> 185     return _compile(pattern, flags).sub(repl, string, count)
#
# File /usr/local/lib/python3.11/site-packages/bert4torch/snippets/data_process.py:289, in lowercase_and_normalize.<locals>.<lambda>(m)
#     287 escaped_special_toks = [re.escape(s_tok) for s_tok in never_split]
#     288 pattern = r"(" + r"|".join(escaped_special_toks) + r")|" + r"(.+?)"
# --> 289 text = re.sub(pattern, lambda m: m.groups()[0] or m.groups()[1].lower(), text)
#     291 # text = text.lower()
#     292 text = unicodedata.normalize('NFD', text)
#
# KeyboardInterrupt:

# %%
just_show()
# Out:
# 日晃百花色    风卷百尺香

# %% [markdown]
# ## 模型恢复 + 测试

# %%
model.load_weights("best_model_v0.pt")

# %%
for upper in [
    '日晃百花色',
    '碧林青旧竹',
    '碧绿',
    '金木',
    '五湖春色满'
]:
    print(u'生成下联:  ', upper, '  ', autotitle.generate(upper, topk=10))
# Out:
# 生成下联:   日晃百花色    风飘百尺风
# 生成下联:   碧林青旧竹    红树绿新枝
# 生成下联:   碧绿    红粉
# 生成下联:   金木    金风
# 生成下联:   五湖春色满    三湘夜色深
